# %% [markdown]
# # LAB ASSIGNMENT-02
# GOPALAM. RAHUL MALIK
# AM.EN.U4EEE20030

# %%
import pandas as pd
import numpy as nump
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('iris_dataset.csv',skiprows=1,header=None)

# %%
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(data[0],data[1])

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Gopalam. Rahul Malik
#AM.EN.U4EEE20030
import numpy as np
import pandas as pd

data=pd.read_csv("iris_dataset.csv",skiprows=1,header=None)
data.head(10)    

# We are splitting data to train and test.  

# Till or except -1 we taking Rest as x values

X=data.iloc[:,:-1].values
Y1=data.iloc[:,-1].values
Y=Y1.reshape(-1,1)
from  sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=41)

#Need to specify or else it take default value.

from sklearn import tree

#We have different classifiers inside this function like tree.decision tree classifiers.

classifier=tree.DecisionTreeClassifier(min_samples_split=3,max_depth=3,criterion="entropy")

#In order to limit 3 layers.

# Method of approach to find the decision value.

classifier.fit(X_train,Y_train)

#Used to training the model
classifier.score(X_test,Y_test)
tree.plot_tree(classifier)

#plotting decision tree
# Out:
# [Text(0.4, 0.875, 'X[2] <= 2.45\nentropy = 1.58\nsamples = 105\nvalue = [39, 32, 34]'),
#  Text(0.2, 0.625, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.6, 0.625, 'X[3] <= 1.75\nentropy = 0.999\nsamples = 66\nvalue = [0, 32, 34]'),
#  Text(0.4, 0.375, 'X[2] <= 5.3\nentropy = 0.323\nsamples = 34\nvalue = [0, 32, 2]'),
#  Text(0.2, 0.125, 'entropy = 0.0\nsamples = 32\nvalue = [0, 32, 0]'),
#  Text(0.6, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.375, 'entropy = 0.0\nsamples = 32\nvalue = [0, 0, 32]')]
